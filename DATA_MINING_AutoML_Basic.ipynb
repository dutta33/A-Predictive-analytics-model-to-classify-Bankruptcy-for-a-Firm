# %%
import os
os.getcwd()
os.chdir('/Users/zaidahmed/Desktop')
import pandas as pd

# %%
file1 = pd.read_csv ('bankruptcy_Train.csv')
file2 = pd.read_csv ('bankruptcy_Test_X.csv',index_col=0)

# %%
#file1.head()
file2.head()
# Out:
#      Attr1   Attr2   Attr3   Attr4   Attr5   Attr6   Attr7   Attr8   Attr9  \
# ID
# 1   0.0481  0.0221  0.5212 -0.0833  0.0076 -0.0160  0.0153 -0.3301  0.1265
# 2   0.0388  0.0542 -0.8472 -0.2481  0.0064  0.0469  0.0119 -0.4428 -0.2527
# 3  -0.0354 -0.0373  0.0661 -0.0898  0.0073 -0.0005  0.0021 -0.0264 -0.3670
# 4   0.0153 -0.0126  0.1425 -0.0722  0.0044  0.0097  0.0112 -0.1789  0.7359
# 5  -0.4917 -0.0688 -0.3381 -0.1579  0.0074 -0.0160 -0.0800  0.2797  0.1616
#
#     Attr10  ...  Attr55  Attr56  Attr57  Attr58  Attr59  Attr60  Attr61  \
# ID          ...
# 1  -0.0168  ... -0.0813  0.0099  0.0172 -0.0101 -0.0182 -0.0414 -0.1646
# 2  -0.0671  ... -0.1773  0.0111  0.0223 -0.0112  0.0010 -0.0357 -0.2001
# 3   0.0574  ... -0.0014  0.0096  0.0061 -0.0098 -0.0196 -0.0413 -0.0941
# 4   0.0271  ...  0.8232  0.0114  0.0112 -0.0114 -0.0196 -0.0341 -0.0237
# 5   0.0982  ... -0.1267  0.0070 -0.0247 -0.0071 -0.0220 -0.0228 -0.1200
#
#     Attr62  Attr63  Attr64
# ID
# 1  -0.0109 -0.3241 -0.0200
# 2  -0.0071 -0.4291 -0.0463
# 3  -0.0152 -0.0688 -0.0372
# 4  -0.0177  0.2895 -0.0303
# 5  -0.0161  0.0295 -0.0390
#
# [5 rows x 64 columns]

# %%
pip install auto_ml
# Out:
# Requirement already satisfied: auto_ml in /anaconda3/lib/python3.7/site-packages (2.9.10)
# Requirement already satisfied: pandas<1.0,>=0.18.0 in /anaconda3/lib/python3.7/site-packages (from auto_ml) (0.24.2)
# Requirement already satisfied: h5py<3.0,>=2.7.0 in /anaconda3/lib/python3.7/site-packages (from auto_ml) (2.9.0)
# Requirement already satisfied: scikit-learn<1.0,>=0.18.1 in /anaconda3/lib/python3.7/site-packages (from auto_ml) (0.20.3)
# Requirement already satisfied: dill<0.3,>=0.2.5 in /anaconda3/lib/python3.7/site-packages (from auto_ml) (0.2.9)
# Requirement already satisfied: pathos<0.3.0,>=0.2.1 in /anaconda3/lib/python3.7/site-packages (from auto_ml) (0.2.5)
# Requirement already satisfied: lightgbm<2.1,>=2.0.11 in /anaconda3/lib/python3.7/site-packages (from auto_ml) (2.0.12)
# Requirement already satisfied: python-dateutil<3.0,>=2.6.1 in /anaconda3/lib/python3.7/site-packages (from auto_ml) (2.8.0)
# Requirement already satisfied: scipy<2.0,>=0.14.0 in /anaconda3/lib/python3.7/site-packages (from auto_ml) (1.2.1)
# Requirement already satisfied: sklearn-deap2<0.3,>=0.2.1 in /anaconda3/lib/python3.7/site-packages (from auto_ml) (0.2.2)
# Requirement already satisfied: numpy<2.0,>=1.11.0 in /anaconda3/lib/python3.7/site-packages (from auto_ml) (1.16.2)
# Requirement already satisfied: tabulate<1.0,>=0.7.5 in /anaconda3/lib/python3.7/site-packages (from auto_ml) (0.8.5)
# Requirement already satisfied: pytz>=2011k in /anaconda3/lib/python3.7/site-packages (from pandas<1.0,>=0.18.0->auto_ml) (2018.9)
# Requirement already satisfied: six in /anaconda3/lib/python3.7/site-packages (from h5py<3.0,>=2.7.0->auto_ml) (1.12.0)
# Requirement already satisfied: multiprocess>=0.70.9 in /anaconda3/lib/python3.7/site-packages (from pathos<0.3.0,>=0.2.1->auto_ml) (0.70.9)
# Requirement already satisfied: pox>=0.2.7 in /anaconda3/lib/python3.7/site-packages (from pathos<0.3.0,>=0.2.1->auto_ml) (0.2.7)
# Requirement already satisfied: ppft>=1.6.6.1 in /anaconda3/lib/python3.7/site-packages (from pathos<0.3.0,>=0.2.1->auto_ml) (1.6.6.1)
# Requirement already satisfied: deap>=1.0.2 in /anaconda3/lib/python3.7/site-packages (from sklearn-deap2<0.3,>=0.2.1->auto_ml) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from auto_ml import Predictor

# %%
file2["Output"] = 0

# %%
file2.head()
# Out:
#      Attr1   Attr2   Attr3   Attr4   Attr5   Attr6   Attr7   Attr8   Attr9  \
# ID
# 1   0.0481  0.0221  0.5212 -0.0833  0.0076 -0.0160  0.0153 -0.3301  0.1265
# 2   0.0388  0.0542 -0.8472 -0.2481  0.0064  0.0469  0.0119 -0.4428 -0.2527
# 3  -0.0354 -0.0373  0.0661 -0.0898  0.0073 -0.0005  0.0021 -0.0264 -0.3670
# 4   0.0153 -0.0126  0.1425 -0.0722  0.0044  0.0097  0.0112 -0.1789  0.7359
# 5  -0.4917 -0.0688 -0.3381 -0.1579  0.0074 -0.0160 -0.0800  0.2797  0.1616
#
#     Attr10  ...  Attr56  Attr57  Attr58  Attr59  Attr60  Attr61  Attr62  \
# ID          ...
# 1  -0.0168  ...  0.0099  0.0172 -0.0101 -0.0182 -0.0414 -0.1646 -0.0109
# 2  -0.0671  ...  0.0111  0.0223 -0.0112  0.0010 -0.0357 -0.2001 -0.0071
# 3   0.0574  ...  0.0096  0.0061 -0.0098 -0.0196 -0.0413 -0.0941 -0.0152
# 4   0.0271  ...  0.0114  0.0112 -0.0114 -0.0196 -0.0341 -0.0237 -0.0177
# 5   0.0982  ...  0.0070 -0.0247 -0.0071 -0.0220 -0.0228 -0.1200 -0.0161
#
#     Attr63  Attr64  Output
# ID
# 1  -0.3241 -0.0200       0
# 2  -0.4291 -0.0463       0
# 3  -0.0688 -0.0372       0
# 4   0.2895 -0.0303       0
# 5   0.0295 -0.0390       0
#
# [5 rows x 65 columns]

# %%
#from auto_ml.utils import get_boston_dataset

# %%
df_train = file1
df_test = file2

# %%
column_descriptions = {'class': 'output'}

ml_predictor = Predictor(type_of_estimator='classifier', column_descriptions=column_descriptions)

ml_predictor.train(df_train)

ml_predictor.score(df_test, df_test.Output)
# Out:
# Welcome to auto_ml! We're about to go through and make sense of your data using machine learning, and give you a production-ready pipeline to get predictions with.
#
# If you have any issues, or new feature ideas, let us know at http://auto.ml
# You are running on version 2.9.10
# Now using the model training_params that you passed in:
# {}
# After overwriting our defaults with your values, here are the final params that will be used to initialize the model:
# {'presort': False, 'learning_rate': 0.1, 'warm_start': True}
# Running basic data cleaning
# Fitting DataFrameVectorizer
# Now using the model training_params that you passed in:
# {}
# After overwriting our defaults with your values, here are the final params that will be used to initialize the model:
# {'presort': False, 'learning_rate': 0.1, 'warm_start': True}
#
#
# ********************************************************************************************
# About to fit the pipeline for the model GradientBoostingClassifier to predict class
# Started at:
# 2019-09-29 01:10:59
# [1] random_holdout_set_from_training_data's score is: -0.021
# [2] random_holdout_set_from_training_data's score is: -0.021
# [3] random_holdout_set_from_training_data's score is: -0.021
# [4] random_holdout_set_from_training_data's score is: -0.021
# [5] random_holdout_set_from_training_data's score is: -0.02
# [6] random_holdout_set_from_training_data's score is: -0.02
# [7] random_holdout_set_from_training_data's score is: -0.02
# [8] random_holdout_set_from_training_data's score is: -0.02
# [9] random_holdout_set_from_training_data's score is: -0.02
# [10] random_holdout_set_from_training_data's score is: -0.019
# [11] random_holdout_set_from_training_data's score is: -0.019
# [12] random_holdout_set_from_training_data's score is: -0.019
# [13] random_holdout_set_from_training_data's score is: -0.019
# [14] random_holdout_set_from_training_data's score is: -0.019
# [15] random_holdout_set_from_training_data's score is: -0.019
# [16] random_holdout_set_from_training_data's score is: -0.019
# [17] random_holdout_set_from_training_data's score is: -0.018
# [18] random_holdout_set_from_training_data's score is: -0.018
# [19] random_holdout_set_from_training_data's score is: -0.018
# [20] random_holdout_set_from_training_data's score is: -0.018
# [21] random_holdout_set_from_training_data's score is: -0.018
# [22] random_holdout_set_from_training_data's score is: -0.018
# [23] random_holdout_set_from_training_data's score is: -0.018
# [24] random_holdout_set_from_training_data's score is: -0.018
# [25] random_holdout_set_from_training_data's score is: -0.018
# [26] random_holdout_set_from_training_data's score is: -0.018
# [27] random_holdout_set_from_training_data's score is: -0.018
# [28] random_holdout_set_from_training_data's score is: -0.018
# [29] random_holdout_set_from_training_data's score is: -0.018
# [30] random_holdout_set_from_training_data's score is: -0.018
# [31] random_holdout_set_from_training_data's score is: -0.018
# [32] random_holdout_set_from_training_data's score is: -0.018
# [33] random_holdout_set_from_training_data's score is: -0.018
# [34] random_holdout_set_from_training_data's score is: -0.018
# [35] random_holdout_set_from_training_data's score is: -0.018
# [36] random_holdout_set_from_training_data's score is: -0.018
# [37] random_holdout_set_from_training_data's score is: -0.018
# [38] random_holdout_set_from_training_data's score is: -0.018
# [39] random_holdout_set_from_training_data's score is: -0.018
# [40] random_holdout_set_from_training_data's score is: -0.018
# [41] random_holdout_set_from_training_data's score is: -0.018
# [42] random_holdout_set_from_training_data's score is: -0.018
# [43] random_holdout_set_from_training_data's score is: -0.018
# [44] random_holdout_set_from_training_data's score is: -0.018
# [45] random_holdout_set_from_training_data's score is: -0.018
# [46] random_holdout_set_from_training_data's score is: -0.018
# [47] random_holdout_set_from_training_data's score is: -0.018
# [48] random_holdout_set_from_training_data's score is: -0.018
# [49] random_holdout_set_from_training_data's score is: -0.018
# [50] random_holdout_set_from_training_data's score is: -0.018
# [52] random_holdout_set_from_training_data's score is: -0.018
# [54] random_holdout_set_from_training_data's score is: -0.018
# [56] random_holdout_set_from_training_data's score is: -0.018
# [58] random_holdout_set_from_training_data's score is: -0.018
# [60] random_holdout_set_from_training_data's score is: -0.018
# [62] random_holdout_set_from_training_data's score is: -0.018
# [64] random_holdout_set_from_training_data's score is: -0.018
# [66] random_holdout_set_from_training_data's score is: -0.018
# [68] random_holdout_set_from_training_data's score is: -0.018
# [70] random_holdout_set_from_training_data's score is: -0.018
# [72] random_holdout_set_from_training_data's score is: -0.018
# [74] random_holdout_set_from_training_data's score is: -0.018
# [76] random_holdout_set_from_training_data's score is: -0.018
# [78] random_holdout_set_from_training_data's score is: -0.018
# The number of estimators that were the best for this training dataset: 44
# The best score on the holdout set: -0.01770186852194283
# Finished training the pipeline!
# Total training time:
# 0:00:15
#
#
# Here are the results from our GradientBoostingClassifier
# predicting class
# Calculating feature responses, for advanced analytics.
# The printed list will only contain at most the top 100 features.
# +----+----------------+--------------+---------+-------------------+-------------------+-----------+-----------+-----------+-----------+
# |    | Feature Name   |   Importance |   Delta |   FR_Decrementing |   FR_Incrementing |   FRD_abs |   FRI_abs |   FRD_MAD |   FRI_MAD |
# |----+----------------+--------------+---------+-------------------+-------------------+-----------+-----------+-----------+-----------|
# | 18 | Attr19         |       0.0000 |  0.5723 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 62 | Attr63         |       0.0000 |  0.5813 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 42 | Attr43         |       0.0000 |  0.6968 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 44 | Attr45         |       0.0000 |  0.7050 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 46 | Attr47         |       0.0000 |  0.4197 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 27 | Attr28         |       0.0000 |  0.1787 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 51 | Attr52         |       0.0000 |  0.1677 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 52 | Attr53         |       0.0000 |  0.3327 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 17 | Attr18         |       0.0000 |  0.0745 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 32 | Attr33         |       0.0000 |  0.5711 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 16 | Attr17         |       0.0000 |  0.5327 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# |  1 | Attr2          |       0.0000 |  0.0474 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# |  3 | Attr4          |       0.0000 |  0.6446 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# |  5 | Attr6          |       0.0000 |  0.3096 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 10 | Attr11         |       0.0000 |  0.3547 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 47 | Attr48         |       0.0002 |  0.3779 |            0.0000 |           -0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 53 | Attr54         |       0.0003 |  0.1761 |           -0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 50 | Attr51         |       0.0005 |  0.4630 |            0.0000 |           -0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 41 | Attr42         |       0.0009 |  0.5446 |            0.0012 |           -0.0001 |    0.0012 |    0.0001 |    0.0005 |    0.0000 |
# | 54 | Attr55         |       0.0011 |  0.5136 |            0.0000 |           -0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 20 | Attr21         |       0.0012 |  0.2990 |            0.0332 |            0.0003 |    0.0332 |    0.0004 |    0.0000 |    0.0000 |
# |  9 | Attr10         |       0.0013 |  0.0595 |           -0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 48 | Attr49         |       0.0016 |  0.5757 |           -0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 11 | Attr12         |       0.0022 |  0.5220 |           -0.0000 |            0.0008 |    0.0000 |    0.0009 |    0.0000 |    0.0000 |
# | 36 | Attr37         |       0.0027 |  0.2989 |           -0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 22 | Attr23         |       0.0030 |  0.5724 |           -0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# |  6 | Attr7          |       0.0030 |  0.0194 |            0.0002 |           -0.0000 |    0.0002 |    0.0000 |    0.0000 |    0.0000 |
# | 61 | Attr62         |       0.0034 |  0.7054 |           -0.0001 |            0.0069 |    0.0001 |    0.0069 |    0.0000 |    0.0019 |
# | 15 | Attr16         |       0.0041 |  0.4811 |            0.0003 |            0.0003 |    0.0003 |    0.0013 |    0.0000 |    0.0000 |
# |  7 | Attr8          |       0.0042 |  0.5395 |           -0.0004 |            0.0004 |    0.0004 |    0.0004 |    0.0000 |    0.0000 |
# | 58 | Attr59         |       0.0052 |  0.7028 |           -0.0000 |            0.0004 |    0.0000 |    0.0004 |    0.0000 |    0.0000 |
# | 40 | Attr41         |       0.0061 |  0.7064 |            0.0694 |           -0.0019 |    0.0694 |    0.0019 |    0.0424 |    0.0008 |
# | 56 | Attr57         |       0.0062 |  0.6653 |            0.0008 |           -0.0000 |    0.0008 |    0.0000 |    0.0000 |    0.0000 |
# | 13 | Attr14         |       0.0068 |  0.0194 |           -0.0001 |            0.0002 |    0.0001 |    0.0002 |    0.0000 |    0.0000 |
# | 63 | Attr64         |       0.0074 |  0.4954 |            0.0000 |           -0.0001 |    0.0000 |    0.0001 |    0.0000 |    0.0000 |
# | 34 | Attr35         |       0.0076 |  0.3961 |            0.0094 |           -0.0007 |    0.0095 |    0.0007 |    0.0000 |    0.0000 |
# | 37 | Attr38         |       0.0084 |  0.0349 |            0.0006 |           -0.0007 |    0.0008 |    0.0008 |    0.0000 |    0.0000 |
# | 59 | Attr60         |       0.0085 |  0.6259 |           -0.0004 |            0.0006 |    0.0004 |    0.0006 |    0.0000 |    0.0000 |
# |  0 | Attr1          |       0.0092 |  0.1077 |           -0.0003 |            0.0002 |    0.0004 |    0.0003 |    0.0000 |    0.0000 |
# | 31 | Attr32         |       0.0099 |  0.1736 |           -0.0001 |            0.0281 |    0.0001 |    0.0281 |    0.0000 |    0.0103 |
# | 49 | Attr50         |       0.0108 |  0.4786 |            0.0032 |           -0.0001 |    0.0032 |    0.0001 |    0.0000 |    0.0000 |
# |  2 | Attr3          |       0.0108 |  0.4844 |           -0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 57 | Attr58         |       0.0118 |  0.7064 |            0.0024 |           -0.0011 |    0.0024 |    0.0027 |    0.0000 |    0.0008 |
# | 29 | Attr30         |       0.0129 |  0.6943 |           -0.0001 |           -0.0001 |    0.0001 |    0.0001 |    0.0000 |    0.0000 |
# | 39 | Attr40         |       0.0155 |  0.6429 |            0.0038 |            0.0069 |    0.0039 |    0.0070 |    0.0000 |    0.0000 |
# | 19 | Attr20         |       0.0160 |  0.7039 |            0.0006 |            0.0010 |    0.0007 |    0.0013 |    0.0000 |    0.0000 |
# |  8 | Attr9          |       0.0160 |  0.5032 |            0.0058 |            0.0000 |    0.0064 |    0.0011 |    0.0000 |    0.0000 |
# | 26 | Attr27         |       0.0163 |  0.6684 |           -0.0071 |            0.0186 |    0.0071 |    0.0187 |    0.0021 |    0.0000 |
# | 38 | Attr39         |       0.0173 |  0.4637 |            0.0528 |           -0.0021 |    0.0529 |    0.0021 |    0.0265 |    0.0000 |
# | 12 | Attr13         |       0.0202 |  0.5735 |            0.0028 |           -0.0040 |    0.0030 |    0.0047 |    0.0002 |    0.0002 |
# | 30 | Attr31         |       0.0210 |  0.5535 |           -0.0003 |            0.0169 |    0.0003 |    0.0169 |    0.0000 |    0.0000 |
# | 21 | Attr22         |       0.0218 |  0.3454 |            0.0017 |           -0.0000 |    0.0023 |    0.0004 |    0.0000 |    0.0000 |
# | 14 | Attr15         |       0.0218 |  0.4434 |           -0.0001 |            0.0241 |    0.0003 |    0.0242 |    0.0000 |    0.0076 |
# | 35 | Attr36         |       0.0232 |  0.4543 |            0.0000 |            0.0012 |    0.0001 |    0.0013 |    0.0000 |    0.0000 |
# | 43 | Attr44         |       0.0233 |  0.6968 |           -0.0002 |            0.0032 |    0.0004 |    0.0032 |    0.0000 |    0.0000 |
# | 25 | Attr26         |       0.0284 |  0.4843 |            0.0241 |           -0.0046 |    0.0243 |    0.0053 |    0.0012 |    0.0004 |
# | 28 | Attr29         |       0.0338 |  0.4979 |           -0.0005 |            0.0007 |    0.0007 |    0.0008 |    0.0000 |    0.0000 |
# | 60 | Attr61         |       0.0410 |  0.5283 |            0.0003 |           -0.0001 |    0.0003 |    0.0003 |    0.0000 |    0.0000 |
# | 45 | Attr46         |       0.0548 |  0.6523 |            0.0607 |           -0.0027 |    0.0609 |    0.0035 |    0.0201 |    0.0000 |
# | 23 | Attr24         |       0.0703 |  0.6529 |            0.0318 |            0.0863 |    0.0337 |    0.0864 |    0.0020 |    0.0099 |
# |  4 | Attr5          |       0.0722 |  0.0717 |           -0.0079 |           -0.0100 |    0.0086 |    0.0105 |    0.0028 |    0.0031 |
# | 24 | Attr25         |       0.0882 |  0.1842 |            0.0035 |           -0.0038 |    0.0047 |    0.0045 |    0.0000 |    0.0000 |
# | 33 | Attr34         |       0.1031 |  0.5230 |           -0.0074 |            0.0114 |    0.0074 |    0.0116 |    0.0000 |    0.0033 |
# | 55 | Attr56         |       0.1443 |  0.7064 |           -0.0015 |            0.0258 |    0.0015 |    0.0258 |    0.0000 |    0.0000 |
# +----+----------------+--------------+---------+-------------------+-------------------+-----------+-----------+-----------+-----------+
#
#
# *******
# Legend:
# Importance = Feature Importance
#      Explanation: A weighted measure of how much of the variance the model is able to explain is due to this column
# FR_delta = Feature Response Delta Amount
#      Explanation: Amount this column was incremented or decremented by to calculate the feature reponses
# FR_Decrementing = Feature Response From Decrementing Values In This Column By One FR_delta
#      Explanation: Represents how much the predicted output values respond to subtracting one FR_delta amount from every value in this column
# FR_Incrementing = Feature Response From Incrementing Values In This Column By One FR_delta
#      Explanation: Represents how much the predicted output values respond to adding one FR_delta amount to every value in this column
# FRD_MAD = Feature Response From Decrementing- Median Absolute Delta
#      Explanation: Takes the absolute value of all changes in predictions, then takes the median of those. Useful for seeing if decrementing this feature provokes strong changes that are both positive and negative
# FRI_MAD = Feature Response From Incrementing- Median Absolute Delta
#      Explanation: Takes the absolute value of all changes in predictions, then takes the median of those. Useful for seeing if incrementing this feature provokes strong changes that are both positive and negative
# FRD_abs = Feature Response From Decrementing Avg Absolute Change
#      Explanation: What is the average absolute change in predicted output values to subtracting one FR_delta amount to every value in this column. Useful for seeing if output is sensitive to a feature, but not in a uniformly positive or negative way
# FRI_abs = Feature Response From Incrementing Avg Absolute Change
#      Explanation: What is the average absolute change in predicted output values to adding one FR_delta amount to every value in this column. Useful for seeing if output is sensitive to a feature, but not in a uniformly positive or negative way
# *******
# Here is our brier-score-loss, which is the default value we optimized for while training, and is the value returned from .score() unless you requested a custom scoring metric
# It is a measure of how close the PROBABILITY predictions are.
# 0.0028
#
# Here is the trained estimator's overall accuracy (when it predicts a label, how frequently is that the correct label?)
# 99.7%
#
# Here is a confusion matrix showing predictions vs. actuals by label:
# Predicted >     0   1   All
# v Actual v
# 0            4987  13  5000
# All          4987  13  5000
#
# Here is predictive value by class:
# Class:  0 = 1.0
# Class:  1 = 0.0
# +----------------------------------+-----------------------------------+--------------------------------+
# | Bucket Edges                     |   Predicted Probability Of Bucket |   Actual Probability of Bucket |
# |----------------------------------+-----------------------------------+--------------------------------|
# | (0.0009499999999999999, 0.00346] |                            0.0033 |                         0.0000 |
# | (0.00346, 0.00376]               |                            0.0036 |                         0.0000 |
# | (0.00376, 0.00412]               |                            0.0039 |                         0.0000 |
# | (0.00412, 0.00543]               |                            0.0047 |                         0.0000 |
# | (0.00543, 0.00749]               |                            0.0066 |                         0.0000 |
# | (0.00749, 0.00976]               |                            0.0086 |                         0.0000 |
# | (0.00976, 0.0138]                |                            0.0115 |                         0.0000 |
# | (0.0138, 0.0219]                 |                            0.0176 |                         0.0000 |
# | (0.0219, 0.0438]                 |                            0.0309 |                         0.0000 |
# | (0.0438, 0.9]                    |                            0.1140 |                         0.0000 |
# +----------------------------------+-----------------------------------+--------------------------------+
#
# Here is the accuracy of our trained estimator at each level of predicted probabilities
# For a verbose description of what this means, please visit the docs:
# http://auto-ml.readthedocs.io/en/latest/analytics.html#interpreting-predicted-probability-buckets-for-classifiers
# -0.0028403292029014395

# %%
ml_predictor.print_results('GD','GradientBoostingClassifier','df_train','df_test')
# Out:
# Calculating feature responses, for advanced analytics.

# %%
a=ml_predictor.predict_proba(df_test)

# %%
len(a)
# Out:
# 5000

# %%
out = list(a)

# %%
zaid = pd.DataFrame(a,columns=["a","b"])

# %%
zaid.to_csv("Trial.csv")
